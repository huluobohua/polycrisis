# %% [markdown]
# <a href="https://colab.research.google.com/github/huluobohua/polycrisis/blob/main/Coding_data_transformations_UNICEFRegion_POwerBI2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://github.com/huluobohua/polycrisis/blob/main/0.%20Polycrisis%20dashboard%20-%20Raw%20data%20for%20Mariana2.xlsx?raw=true

# %% [markdown]
# # Coding data transformations
#
# First, let's mount Google Drive so we can load files from Google Drive Folders.

# %%
#/* from google.colab import drive
#drive.mount('/content/gdrive')
#%cd /content/gdrive/'Shared with me'/'Unicef Foresight and Policy' */
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: '/content/gdrive/Shared with me/Unicef Foresight and Policy/'
# /content

# %% [markdown]
# Then, we'll load the file that contains the data to be dispayed.

# %%
#Locate file
import pandas as pd
import openpyxl
f = 'https://github.com/huluobohua/polycrisis/blob/main/0.%20Polycrisis%20dashboard%20-%20Raw%20data%20for%20Mariana2.xlsx?raw=true'

# %% [markdown]
# ### GBP indicator B

# %%
#Load xlsx sheet
import numpy as np
import pandas as pd
df1 = pd.read_excel(f,
  sheet_name="GDP indicator B",
  skiprows=1,
  nrows=197,
  usecols="A:I"
);

df1.head()
# Out:
#   ISO Code  IMF growth forecast for 2023 in Oct 21  \
# 0      ABW                                   6.200
# 1      AFG                                     NaN
# 2      AGO                                   3.328
# 3      AIA                                     NaN
# 4      ALB                                   4.100
#
#    IMF growth forecast for 2023 in Oct 22 ISO3  CountryName  \
# 0                                   1.950  ABW        Aruba
# 1                                     NaN  AFG  Afghanistan
# 2                                   3.427  AGO       Angola
# 3                                     NaN  AIA      Anguila
# 4                                   2.500  ALB      Albania
#
#                    UNSubRegionName UNICEFRegionCode  NATCOM  Programme
# 0  Latin America and the Caribbean              NaN       0          0
# 1                    Southern Asia               SA       0          1
# 2               Sub-Saharan Africa              ESA       0          1
# 3  Latin America and the Caribbean              CAO       0          1
# 4                  Southern Europe              ECA       0          1

# %%
#Replicate column C using A1 and A2
a1_gdpb = "IMF growth forecast for 2023 in Oct 21"
a2_gdpb = "IMF growth forecast for 2023 in Oct 22"

df1_c = ( df1[a2_gdpb] - df1[a1_gdpb] ) / abs(df1[a1_gdpb]) #operation


df1_c.head()
# Out:
# 0   -0.685484
# 1         NaN
# 2    0.029748
# 3         NaN
# 4   -0.390244
# dtype: float64

# %%
#Replicate column D using C

df1_d = df1_c + abs( df1_c.min() ) #operation

df1_d.head()
# Out:
# 0    1.454516
# 1         NaN
# 2    2.169748
# 3         NaN
# 4    1.749756
# dtype: float64

# %%
#Replicate column I using D

#normalisation
q1, q3 = df1_d.quantile(.25), df1_d.quantile(.75)
outlier_uppercut = q3 + 2*(q3-q1)
filter = df1_d.between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((d-df1_d.min())/(df1_d[filter].max()-df1_d.min()) if d < outlier_uppercut
     else (1. if not np.isnan(d) else np.nan))
     for d in df1_d 
])

#reindexing
df1_i = 10 - 10*(normalisation)
df1_i.head()
df1["GDPindex"]=df1_i

# %% [markdown]
# ### Food inflation indicator

# %%
#Load xlsx sheet
df2 = pd.read_excel(f,
  sheet_name="Food inflation indicator",
  skiprows=1,
  nrows=197,
  usecols="A:J"
);

df2.head()
# Out:
#        Country  ISO  Food inflation  Food inflation shifted right ISO3  \
# 0        Aruba  ABW           11.53                         12.51  ABW
# 1  Afghanistan  AFG           17.59                         18.57  AFG
# 2       Angola  AGO           16.80                         17.78  AGO
# 3      Anguila  AIA             NaN                           NaN  AIA
# 4      Albania  ALB           15.30                         16.28  ALB
#
#    CountryName                  UNSubRegionName UNICEFRegionCode  NATCOM  \
# 0        Aruba  Latin America and the Caribbean              NaN       0
# 1  Afghanistan                    Southern Asia               SA       0
# 2       Angola               Sub-Saharan Africa              ESA       0
# 3      Anguila  Latin America and the Caribbean              CAO       0
# 4      Albania                  Southern Europe              ECA       0
#
#    Programme
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1

# %%
#Replicate column B using A
a_fii = "Food inflation"
b_fii = "Food inflation shifted right"

df2_b = df2[a_fii] + abs(df2[a_fii].min()) #operation
assert all( df2_b.dropna() == df2[b_fii].dropna() ) #sanity check

df2_b.head()
# Out:
# 0    12.51
# 1    18.57
# 2    17.78
# 3      NaN
# 4    16.28
# Name: Food inflation, dtype: float64

# %%
#Replicate column I*10 using B
i_fii = "Normalized*10"

#normalisation
q1, q3 = df2_b.quantile(.25), df2_b.quantile(.75)
outlier_uppercut = q3 + 2*(q3-q1) 
#q3 + 2*(q3-q1) there is a manual override in the sheet
filter = df2_b.between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((b-df2_b.min())/(df2_b[filter].max()-df2_b.min()) if b < outlier_uppercut
     else (1. if not np.isnan(b) else np.nan))
     for b in df2_b 
])

#reindexing
df2_i = 10*(normalisation)
df2_i
df2["FoodInfIndex"] = df2_i

# %% [markdown]
# ### Credit Score indicator

# %%
#Load xlsx sheet
df3 = pd.read_excel(f,
  sheet_name="Credit Score indicator",
  skiprows=1,
  nrows=197,
  usecols="A:G"
);

df3.head()
# Out:
#        Country  ISO  Credit rating average  \
# 0        Aruba  ABW                   11.5
# 1  Afghanistan  AFG                    NaN
# 2       Angola  AGO                    6.0
# 3      Albania  AIA                    NaN
# 4      Andorra  ALB                    8.0
#
#    Credit rating average inverted (to make more positive worse)  \
# 0                                                9.5
# 1                                                NaN
# 2                                               15.0
# 3                                                NaN
# 4                                               13.0
#
#    Credit rating average normalized * 10 (values in red are imputted - exclude from indexation range)  \
# 0                                           4.523810
# 1                                           7.500000
# 2                                           7.142857
# 3                                                NaN
# 4                                           6.190476
#
#    ImputedIMF4Levels ISO3
# 0                NaN  ABW
# 1                1.0  AFG
# 2                NaN  AGO
# 3                NaN  AIA
# 4                NaN  ALB

# %%
#Replicate column B using A
a_csi = "Credit rating average"
b_csi = "Credit rating average inverted (to make more positive worse)"

df3_b = 21. - df3[a_csi] #operation
assert all( df3_b.dropna() == df3[b_csi].dropna() ) #sanity check

df3_b.head()
# Out:
# 0     9.5
# 1     NaN
# 2    15.0
# 3     NaN
# 4    13.0
# Name: Credit rating average, dtype: float64

# %%
#Replicate column I*10 using B
i_csi = "Credit rating average normalized * 10 (values in red are imputted - exclude from indexation range)"

#normalisation
q1, q3 = df3[a_csi].quantile(.25), df3[a_csi].quantile(.75) #using column A
# q1, q3 = df3_b.quantile(.25), df3_b.quantile(.75) #using column B
outlier_uppercut = q3 + 2*(q3-q1)
filter = df3_b.between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((b-df3_b.min())/(df3_b[filter].max()-df3_b.min()) if b < outlier_uppercut
     else (1. if not np.isnan(b) else np.nan))
     for b in df3_b 
])

#reindexing
df3_i = 10*(normalisation)
df3_i
df3["CreditRateIndex"] =df3_i

# %% [markdown]
# ### External conflict risk

# %%
#Load xlsx sheet
df4 = pd.read_excel(f,
  sheet_name="External conflict risk",
  skiprows=1,
  nrows=197,
  usecols="A:G"
);

df4.head()
# Out:
#   ISO3  GPI Militarization 2022  GPI Relationship with neighbors 2022  \
# 0  ABW                      NaN                                   NaN
# 1  AFG                    2.472                                 4.336
# 2  AGO                    1.706                                 3.345
# 3  AIA                      NaN                                   NaN
# 4  ALB                    1.666                                 2.899
#
#    Current external conflict (5 if current; 3 if probable or stand-off; 0 if none)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    GPI External Components  CountryName                  UNSubRegionName
# 0                      NaN        Aruba  Latin America and the Caribbean
# 1                 2.269333  Afghanistan                    Southern Asia
# 2                 1.683667       Angola               Sub-Saharan Africa
# 3                      NaN      Anguila  Latin America and the Caribbean
# 4                 1.521667      Albania                  Southern Europe

# %%
#Replicate column C123 using A1, A2  and A3
a1_ecr = "GPI Militarization 2022"
a2_ecr = "GPI Relationship with neighbors 2022"
a3_ecr = "Current external conflict (5 if current; 3 if probable or stand-off; 0 if none)"
c123_ecr = "GPI External Components"

df4_c123 = ( df4[a1_ecr]+df4[a2_ecr]+df4[a3_ecr] )/3 #operation
assert all( df4_c123.dropna() == df4[c123_ecr].dropna() ) #sanity check

df4_c123.head()
# Out:
# 0         NaN
# 1    2.269333
# 2    1.683667
# 3         NaN
# 4    1.521667
# dtype: float64

# %%
#Replicate column I using C123
i_ecr = "GPI external components normalized"

#normalisation
q1, q3 = df4_c123.quantile(.25), df4_c123.quantile(.75) #using column C123
outlier_uppercut = q3 + 2*(q3-q1)
filter = df4_c123.between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((c-df4_c123.min())/(df4_c123[filter].max()-df4_c123.min()) if c < outlier_uppercut
     else (1. if not np.isnan(c) else np.nan))
     for c in df4_c123 
])

#reindexing
df4_i = 10*(normalisation)
df4_i
df4["ExternalConflictIndex"] = df4_i

# %% [markdown]
# ### Political stability abs conf

# %%
#Load xlsx sheet
df5 = pd.read_excel(f,
  sheet_name="Political stability abs conf",
  skiprows=1,
  nrows=197,
  usecols="A:J"
)

df5.head()
# Out:
#   ISO Code_orig  WGI (political stability)  2021 WGI Political stability  \
# 0           ABW                   0.364940                      1.474335
# 1           AFG                   9.644537                     -2.529855
# 2           AGO                   5.429013                     -0.710836
# 3           AIA                        NaN                           NaN
# 4           ALB                   3.528032                      0.109446
#
#    WGI normalized ISO3  CountryName                  UNSubRegionName  \
# 0        0.364940  ABW        Aruba  Latin America and the Caribbean
# 1        9.644537  AFG  Afghanistan                    Southern Asia
# 2        5.429013  AGO       Angola               Sub-Saharan Africa
# 3             NaN  AIA      Anguila  Latin America and the Caribbean
# 4        3.528032  ALB      Albania                  Southern Europe
#
#   UNICEFRegionCode  NATCOM  Programme
# 0              NaN       0          0
# 1               SA       0          1
# 2              ESA       0          1
# 3              CAO       0          1
# 4              ECA       0          1

# %%
#Replicate column I using A
a_psac = "2021 WGI Political stability"
i_psac = "WGI normalized"

#normalisation
q1, q3 = df5[a_psac].quantile(.25), df5[a_psac].quantile(.75) #using column A
outlier_uppercut = q3 + 2*(q3-q1)
filter = df5[a_psac].between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((a-df5[a_psac].min())/(df5[a_psac][filter].max()-df5[a_psac].min()) if a < outlier_uppercut
     else (1. if not np.isnan(a) else np.nan))
     for a in df5[a_psac]
])

#reindexing
df5_i = 10 - 10*(normalisation)
df5_i
df5["PolStabIndex"] = df5_i

# %% [markdown]
# ### Climate indicator

# %%
#Load xlsx sheet
df6 = pd.read_excel(f,
  sheet_name="Climate indicator",
  skiprows=1,
  nrows=197,
  usecols="A:K"
);

df6.head()
# Out:
#    ISO ISO Code  ND-GAIN Climate Vulnerability Index ISO Code.1  \
# 0  ABW      ABW                                  NaN        ABW
# 1  AFG      AFG                             0.579128        AFG
# 2  AGO      AGO                             0.505320        AGO
# 3  AIA      AIA                                  NaN        NaN
# 4  ALB      ALB                             0.414296        ALB
#
#    Climate index taken to 10 point scale ISO3  CountryName  \
# 0                                    NaN  ABW        Aruba
# 1                               7.718004  AFG  Afghanistan
# 2                               5.959143  AGO       Angola
# 3                                    NaN  AIA      Anguila
# 4                               3.789999  ALB      Albania
#
#                    UNSubRegionName UNICEFRegionCode  NATCOM  Programme
# 0  Latin America and the Caribbean              NaN       0          0
# 1                    Southern Asia               SA       0          1
# 2               Sub-Saharan Africa              ESA       0          1
# 3  Latin America and the Caribbean              CAO       0          1
# 4                  Southern Europe              ECA       0          1

# %%
#Replicate column I using A
a_ci = "ND-GAIN Climate Vulnerability Index"
i_ci = "Climate index taken to 10 point scale"

#normalisation
q1, q3 = df6[a_ci].quantile(.25), df6[a_ci].quantile(.75)
outlier_uppercut = q3 + 2*(q3-q1)
q1,q3,outlier_uppercut
filter = df6[a_ci].between(q1, outlier_uppercut, inclusive="both")
normalisation = pd.Series([
    #operation
     ((a-df6[a_ci].min())/(df6[a_ci][filter].max()-df6[a_ci].min()) if a < outlier_uppercut
     else (1. if not np.isnan(a) else np.nan))
     for a in df6[a_ci]
])

#reindexing
df6_i = 10*(normalisation)
df6_i
df6["ClimateIndex"] = df6_i

# %%
df1.head()
# Out:
#   ISO Code  IMF growth forecast for 2023 in Oct 21  \
# 0      ABW                                   6.200
# 1      AFG                                     NaN
# 2      AGO                                   3.328
# 3      AIA                                     NaN
# 4      ALB                                   4.100
#
#    IMF growth forecast for 2023 in Oct 22 ISO3  CountryName  \
# 0                                   1.950  ABW        Aruba
# 1                                     NaN  AFG  Afghanistan
# 2                                   3.427  AGO       Angola
# 3                                     NaN  AIA      Anguila
# 4                                   2.500  ALB      Albania
#
#                    UNSubRegionName UNICEFRegionCode  NATCOM  Programme  \
# 0  Latin America and the Caribbean              NaN       0          0
# 1                    Southern Asia               SA       0          1
# 2               Sub-Saharan Africa              ESA       0          1
# 3  Latin America and the Caribbean              CAO       0          1
# 4                  Southern Europe              ECA       0          1
#
#    GDPindex
# 0  4.832758
# 1       NaN
# 2  2.291863
# 3       NaN
# 4  3.783903

# %%
df2.head()
# Out:
#        Country  ISO  Food inflation  Food inflation shifted right ISO3  \
# 0        Aruba  ABW           11.53                         12.51  ABW
# 1  Afghanistan  AFG           17.59                         18.57  AFG
# 2       Angola  AGO           16.80                         17.78  AGO
# 3      Anguila  AIA             NaN                           NaN  AIA
# 4      Albania  ALB           15.30                         16.28  ALB
#
#    CountryName                  UNSubRegionName UNICEFRegionCode  NATCOM  \
# 0        Aruba  Latin America and the Caribbean              NaN       0
# 1  Afghanistan                    Southern Asia               SA       0
# 2       Angola               Sub-Saharan Africa              ESA       0
# 3      Anguila  Latin America and the Caribbean              CAO       0
# 4      Albania                  Southern Europe              ECA       0
#
#    Programme  FoodInfIndex
# 0          0      2.601913
# 1          1      3.862313
# 2          1      3.698003
# 3          1           NaN
# 4          1      3.386023

# %%
df3.head()
# Out:
#        Country  ISO  Credit rating average  \
# 0        Aruba  ABW                   11.5
# 1  Afghanistan  AFG                    NaN
# 2       Angola  AGO                    6.0
# 3      Albania  AIA                    NaN
# 4      Andorra  ALB                    8.0
#
#    Credit rating average inverted (to make more positive worse)  \
# 0                                                9.5
# 1                                                NaN
# 2                                               15.0
# 3                                                NaN
# 4                                               13.0
#
#    Credit rating average normalized * 10 (values in red are imputted - exclude from indexation range)  \
# 0                                           4.523810
# 1                                           7.500000
# 2                                           7.142857
# 3                                                NaN
# 4                                           6.190476
#
#    ImputedIMF4Levels ISO3  CreditRateIndex
# 0                NaN  ABW         4.523810
# 1                1.0  AFG              NaN
# 2                NaN  AGO         7.142857
# 3                NaN  AIA              NaN
# 4                NaN  ALB         6.190476

# %%
df4.head()
# Out:
#   ISO3  GPI Militarization 2022  GPI Relationship with neighbors 2022  \
# 0  ABW                      NaN                                   NaN
# 1  AFG                    2.472                                 4.336
# 2  AGO                    1.706                                 3.345
# 3  AIA                      NaN                                   NaN
# 4  ALB                    1.666                                 2.899
#
#    Current external conflict (5 if current; 3 if probable or stand-off; 0 if none)  \
# 0                                                0.0
# 1                                                0.0
# 2                                                0.0
# 3                                                NaN
# 4                                                0.0
#
#    GPI External Components  CountryName                  UNSubRegionName  \
# 0                      NaN        Aruba  Latin America and the Caribbean
# 1                 2.269333  Afghanistan                    Southern Asia
# 2                 1.683667       Angola               Sub-Saharan Africa
# 3                      NaN      Anguila  Latin America and the Caribbean
# 4                 1.521667      Albania                  Southern Europe
#
#    ExternalConflictIndex
# 0                    NaN
# 1               6.827930
# 2               3.906899
# 3                    NaN
# 4               3.098919

# %%
df5.head()
# Out:
#   ISO Code_orig  WGI (political stability)  2021 WGI Political stability  \
# 0           ABW                   0.364940                      1.474335
# 1           AFG                   9.644537                     -2.529855
# 2           AGO                   5.429013                     -0.710836
# 3           AIA                        NaN                           NaN
# 4           ALB                   3.528032                      0.109446
#
#    WGI normalized ISO3  CountryName                  UNSubRegionName  \
# 0        0.364940  ABW        Aruba  Latin America and the Caribbean
# 1        9.644537  AFG  Afghanistan                    Southern Asia
# 2        5.429013  AGO       Angola               Sub-Saharan Africa
# 3             NaN  AIA      Anguila  Latin America and the Caribbean
# 4        3.528032  ALB      Albania                  Southern Europe
#
#   UNICEFRegionCode  NATCOM  Programme  PolStabIndex
# 0              NaN       0          0      0.364940
# 1               SA       0          1      9.644537
# 2              ESA       0          1      5.429013
# 3              CAO       0          1           NaN
# 4              ECA       0          1      3.528032

# %%
df6.head()
# Out:
#    ISO ISO Code  ND-GAIN Climate Vulnerability Index ISO Code.1  \
# 0  ABW      ABW                                  NaN        ABW
# 1  AFG      AFG                             0.579128        AFG
# 2  AGO      AGO                             0.505320        AGO
# 3  AIA      AIA                                  NaN        NaN
# 4  ALB      ALB                             0.414296        ALB
#
#    Climate index taken to 10 point scale ISO3  CountryName  \
# 0                                    NaN  ABW        Aruba
# 1                               7.718004  AFG  Afghanistan
# 2                               5.959143  AGO       Angola
# 3                                    NaN  AIA      Anguila
# 4                               3.789999  ALB      Albania
#
#                    UNSubRegionName UNICEFRegionCode  NATCOM  Programme  \
# 0  Latin America and the Caribbean              NaN       0          0
# 1                    Southern Asia               SA       0          1
# 2               Sub-Saharan Africa              ESA       0          1
# 3  Latin America and the Caribbean              CAO       0          1
# 4                  Southern Europe              ECA       0          1
#
#    ClimateIndex
# 0           NaN
# 1      7.718004
# 2      5.959143
# 3           NaN
# 4      3.789999
